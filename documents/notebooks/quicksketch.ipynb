# %%
import os
import numpy as np
from scipy.io import mmread
# Out:
# /Users/luciusvo/Documents/GitHub/meliso/documents/notebooks

# %%
A = mmread("../../inputs/matrices/Iperturb.mtx")
x = np.loadtxt("../../inputs/vectors/input_x.txt")
A @ x[:A.shape[0]]
# Out:
# array([0.92910147, 0.94153128, 0.68125481, 0.03017197, 0.80875179,
#        0.33313626, 0.06109079, 0.91946737, 0.82832826, 0.05870282,
#        0.28262622, 0.02984776, 0.84756295, 0.1870501 , 0.87225428,
#        0.22277945, 0.74531948, 0.10965378, 0.19585096, 0.31221911,
#        0.43209269, 0.72187116, 0.13534519, 0.25292821, 0.47525389,
#        0.35516105, 0.75571489, 0.96403207, 0.46559732, 0.65401457,
#        0.36161557, 0.94971823, 0.86195277, 0.87361637, 0.31353008,
#        0.5677777 , 0.47744877, 0.85106036, 0.54578666, 0.67976504,
#        0.21655243, 0.90690113, 0.66706655, 0.87682351, 0.76551419,
#        0.52978644, 0.94311505, 0.76292905, 0.11605971, 0.20882431,
#        0.05336501, 0.17105569, 0.144975  , 0.82489481, 0.8962962 ,
#        0.01042544, 0.27704574, 0.65706165, 0.12909833, 0.63412837,
#        0.6658628 , 0.48267415, 0.75680517, 0.38698177, 0.21794279,
#        0.08241032])
