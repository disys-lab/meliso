# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

plt.rcParams["font.family"] = "serif"
plt.rcParams["text.usetex"] = True
plt.rcParams["figure.dpi"] = 1000
plt.rcParams["font.size"] = 14
plt.rcParams["legend.fontsize"] = 14
plt.rcParams["xtick.direction"] = "in"
plt.rcParams["ytick.direction"] = "in"
plt.rcParams["xtick.major.size"] = 5.0
plt.rcParams["xtick.minor.size"] = 3.0
plt.rcParams["ytick.major.size"] = 5.0
plt.rcParams["ytick.minor.size"] = 3.0
plt.rcParams["axes.linewidth"] = 0.8
plt.rcParams["legend.handlelength"] = 2.0

# %%
itersExp = {
    "Material": ["Ag-aSi", "Ag-aSi", "Ag-aSi", "Ag-aSi", "Ag-aSi", "Ag-aSi", "Ag-aSi",
                 "AlOx-HfO2", "AlOx-HfO2", "AlOx-HfO2", "AlOx-HfO2", "AlOx-HfO2", "AlOx-HfO2", "AlOx-HfO2",
                 "EpiRAM", "EpiRAM", "EpiRAM", "EpiRAM", "EpiRAM", "EpiRAM", "EpiRAM",
                 "TaOx-HfOx", "TaOx-HfOx", "TaOx-HfOx", "TaOx-HfOx", "TaOx-HfOx", "TaOx-HfOx", "TaOx-HfOx"],
    "No. iteration": [1, 3, 5, 10, 20, 50, 100, 
                      1, 3, 5, 10, 20, 50, 100, 
                      1, 3, 5, 10, 20, 50, 100,
                      1, 3, 5, 10, 20, 50, 100],
    "L2 Error": [47.6725, 21.8566, 11.9898, 1.5875, 1.1816, 1.6919, 1.1607, 
                 98.5239, 3.5895, 4.6886, 4.6543, 4.7382, 3.5014, 4.0574, 
                 4.5451, 5.0008, 5.1521, 5.0639, 5.0920, 5.1349, 5.1012, 
                 69.1190, 3.8112, 3.7941, 3.8228, 3.8203, 3.7895, 3.9280],
    "L-infty Error": [6.5705, 3.2246, 2.0149, 0.4703, 0.4703, 0.4703, 0.3681, 
                      13.1680, 0.7271, 0.9475, 0.9633, 0.9693, 0.8219, 0.8987, 
                      0.7551, 0.8355, 0.8600, 0.8464, 0.8552, 0.8552, 0.8552, 
                      9.1401, 0.6952, 0.7022, 0.7041, 0.7051, 0.7176, 0.7176],
    "Write Latency": [280.7771, 391.1238, 429.4766, 448.5018, 457.1104, 452.9401, 456.0266,
                      38.8019, 72.8766, 75.4257, 76.2362, 75.7169, 75.4479, 75.9185,
                      0.0448, 0.0478, 0.0479, 0.0479, 0.0479, 0.0479, 0.0478,
                      0.0622, 0.0882, 0.0883, 0.0884, 0.0884, 0.0884, 0.0885],
    "Write Energy": [1.2425E-03, 1.8339E-03, 2.0080E-03, 2.0519E-03, 2.0634E-03, 2.0813E-03, 2.0985E-03,
                      1.8313E-02, 3.8615E-02, 4.0570E-02, 4.1192E-02, 4.0890E-02, 4.0579E-02, 4.0870E-02,
                      1.3223E-04, 1.3391E-04, 1.3392E-04, 1.3392E-04, 1.3392E-04, 1.3392E-04, 1.3392E-04,
                      1.8068E-05, 2.7966E-05, 2.8022E-05, 2.8091E-05, 2.8150E-05, 2.8378E-05, 2.8810E-05], 
}

df = pd.DataFrame(itersExp)

# %%
materials = df["Material"].unique()
fig, axs = plt.subplots(len(materials), 1, figsize=(8, 15))

for i, material in enumerate(materials):
    material_data = df[df["Material"] == material]
    ax1 = axs[i]
    
    # Plot L2 Error on the primary y-axis
    ax1.plot(material_data["No. iteration"], material_data["L2 Error"], label="L2 Error", 
             marker="o", color="blue")
    ax1.set_ylabel("$l^2$-norm Error", color="tab:red")    
    ax1.set_title(f"{material}")
    ax1.grid(True)
    
    # Plot L-infty Error on the secondary y-axis
    ax2 = ax1.twinx()
    ax2.plot(material_data["No. iteration"], material_data["L-infty Error"], label="L-infty Error", 
             marker="o", color="red")
    ax2.set_ylabel("$l^\infty$-norm Error", color="tab:blue")
    ax2.set_yscale("log")

# Set common x-axis label
plt.xlabel("No. iteration")
plt.tight_layout()
plt.show()

# %%
# Create subplots for L-2 Norm Error and L-infty Norm Error
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

# Plot L2 Error on the first subplot
ax1.set_xlabel("No. iteration")
ax1.set_ylabel("$l^2$-norm Error", color="tab:blue")
for material in df["Material"].unique():
    material_data = df[df["Material"] == material]
    ax1.plot(material_data["No. iteration"], material_data["L2 Error"], 
             marker="o", linestyle="solid", label=f"{material}")

ax1.tick_params(axis="y", labelcolor="tab:blue")
ax1.grid(True)
ax1.legend(title="Material")
ax1.set_yscale("log")

# Plot L-infty Error on the second subplot
ax2.set_xlabel("No. iteration")
ax2.set_ylabel("$l^\infty$-norm Error", color="tab:red")
for material in df["Material"].unique():
    material_data = df[df["Material"] == material]
    ax2.plot(material_data["No. iteration"], material_data["L-infty Error"], 
             marker="o", linestyle="solid", label=f"{material}")

ax2.tick_params(axis="y", labelcolor="tab:red")
ax2.grid(True)
ax2.legend(title="Material")
ax2.set_yscale("log")
# Adjust layout
fig.tight_layout()

plt.show()
